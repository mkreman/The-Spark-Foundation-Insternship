# %% [markdown]
# Name of Intern : $\textbf{Mayank Nagar}$

# %% [markdown]
# **Task - 1**
#
# Linear Regression

# %% [markdown]
# Importing Necessary Libraries

# %%
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load The Dataset

# %%
data = pd.read_csv('student_scores - student_scores.csv')
print(data.head())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# Let's plot our data points on 2-D graph to eyeball our dataset and see if we can manually find any relationship between the data.

# %%
plt.subplots(figsize = (12,8))
plt.scatter(data['Hours'], data['Scores'])
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')
plt.show()

# %% [markdown]
# **As we can see from above plot that there is a linear relation between Hours Studied and Percentage Score.**

# %% [markdown]
# # Preparing The Data

# %%
X = data['Hours'].values.reshape(25, 1)
y = data['Scores']

# %% [markdown]
# Spliting the dataset into training and test dataset.

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# # Training the algorithm.

# %%
model = linear_model.LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Making Predictions

# %%
prediction = model.predict(x_test)
print('R^2 value: ', model.score(X, y))
# Out:
# R^2 value:  0.952911106425492

# %% [markdown]
# Ploting the predicted features.

# %%
plt.subplots(figsize = (12,8))
plt.scatter(x_train, y_train)
plt.scatter(x_test, prediction, c='red')
plt.scatter(x_test, y_test, c='green')
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')
plt.legend(['Training', 'Predicted', 'Testing'])
plt.show()

# %% [markdown]
# Plotting the regression line

# %%
line = model.coef_*X+model.intercept_

plt.subplots(figsize = (12,8))
plt.scatter(X, y)
plt.plot(X, line);
plt.show()
